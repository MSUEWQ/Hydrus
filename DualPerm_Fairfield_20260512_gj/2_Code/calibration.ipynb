# %% [markdown]
# ## Set Up

# %% [markdown]
# Before running code, type into terminal:
#
#     py -3.12 -m venv venv
# ^this creates the virtual enviornment with Python 3.12
#
#     venv\Scripts\activate
# ^this activates the virtual environment
#
#     python -m pip install -r requirements.txt
# ^this installs packages according to the requirements.txt file

# %%
from pathlib import Path
from typing import Union, Optional
import copy
import numpy as np
np.random.seed(42)
import matplotlib.pyplot as pltvenv
from matplotlib import axes
import xarray as xr
import pandas as pd
from spotpy.algorithms import _algorithm
import spotpy
import tqdm
from scipy.stats import wasserstein_distance
import dask.array as da
import datetime 
import os
import matplotlib.pyplot as plt #this works for Meghan using version 3.10.7

# %%
from hydrus_setup import HydrusSetup
from MS_CUA import MsCua, SensitivityAnalysis, MsCuaAnalyzer

# %%
#give path to exe file
exe = os.path.join(os.getcwd(), "H1D_CALC.EXE")

#name the folder files will fill
main_level = os.path.normpath(os.path.join(os.getcwd(), os.pardir))

# %%
# Identify file names/paths for input data
input_files = [f for f in os.listdir(os.path.join(main_level, '1_Input',))]

weather_csv = [s for s in input_files if "weather" in s.lower()][0]
irgn_csv = [s for s in input_files if "irrigation" in s.lower()][0]
obs_csv = [s for s in input_files if "observation" in s.lower()][0]
vg_csv = [s for s in input_files if "vg" in s.lower()][0]
crop_csv = [s for s in input_files if "crop" in s.lower()][0]
gdd_csv = [s for s in input_files if "gdd" in s.lower()][0]
calib_csv = [f for f in os.listdir(os.path.join(main_level, '1_Input', 'FieldData', 'CalibrationData'))][0]

# %%
# Load and clean calib data
calib = pd.read_csv(os.path.join(main_level, '1_Input', 'FieldData',  'CalibrationData', calib_csv))
calib["Date"] = pd.to_datetime(calib["Date"])

# filter calibration data to be contrained by weather data time period (which dictates hydrus output period)
weather_df = pd.read_csv(os.path.join(main_level, '1_Input', weather_csv))
weather_df['Date'] = pd.to_datetime(weather_df['Date'])
calib = calib.loc[(calib['Date'] >= min(weather_df.Date)) & (calib['Date'] <= max(weather_df.Date)), ]

# %%
def add_gdds(weatherdata, cropdates):
    weatherdata['gdds']=0
    weatherdata['Year']= "NA"

    for i in range(len(weatherdata)):
        weatherdata['Year'][i] = weatherdata.Date.dt.year[i]

    weatherdata['Year'] = weatherdata['Year'].astype(int)

    weatherdata = weatherdata.merge(cropdates, on= "Year").rename(columns={'Seeding': 'StartDate','Harvest': 'EndDate'})
    weatherdata['StartDate'] = pd.to_datetime(weatherdata['StartDate'])
    weatherdata['EndDate'] = pd.to_datetime(weatherdata['EndDate'])
    weatherdata['Date'] = pd.to_datetime(weatherdata['Date'])

    for i in range(1,len(weatherdata)):
        if (weatherdata['Date'][i] >= weatherdata['StartDate'][i] and weatherdata['Date'][i] <= weatherdata['EndDate'][i] and weatherdata['AvgTemp'][i] > 0):
            weatherdata['gdds'][i] = weatherdata['gdds'][i-1] + weatherdata['AvgTemp'][i]
            weatherdata['gdds'][i:len(weatherdata)] = weatherdata['gdds'][i-1] + weatherdata['AvgTemp'][i]
        # reset gdds to 0 at the end of each year
        if (weatherdata['Date'][i] == weatherdata['EndDate'][i]):
            weatherdata['gdds'][i:len(weatherdata)] = 0
    
    return weatherdata

def partition_et(weatherdata, gddinfo):
    
    fallow_coef = gddinfo.loc[gddinfo['crop'] == 'Fallow']['max.coef']

    weatherdata['t_coef'] = 0
    weatherdata['e_coef'] = 0.22
  
    for i in range(len(weatherdata)):
        crop = weatherdata['Crop'][i]
        max_coef = gddinfo.loc[gddinfo['crop'] == crop]['max.coef']
        
        check1 = (weatherdata['gdds'][i] > (gddinfo.loc[gddinfo['crop'] == crop]['gdd2emergence']).astype(int))& (weatherdata['gdds'][i] <= (gddinfo.loc[gddinfo['crop'] == crop]['gdd2close']).astype(int))
        check1 = all(check1)

        if check1 == True:
            weatherdata['t_coef'][i] = (weatherdata['gdds'][i] - gddinfo.loc[gddinfo['crop'] == crop]['gdd2emergence'])*max_coef/(gddinfo.loc[gddinfo['crop'] == crop]['gdd2close']-gddinfo.loc[gddinfo['crop'] == crop]['gdd2emergence'])

        check2 = (weatherdata['gdds'][i] > (gddinfo.loc[gddinfo['crop'] == crop]['gdd2close']).astype(int))& (weatherdata['gdds'][i] <= (gddinfo.loc[gddinfo['crop'] == crop]['gdd2mature']).astype(int))
        check2 = all(check2)

        if check2 == True:
            weatherdata['t_coef'][i] = max_coef
        
        check3 = (weatherdata['gdds'][i] > (gddinfo.loc[gddinfo['crop'] == crop]['gdd2mature']).astype(int))& (weatherdata['gdds'][i] <= (gddinfo.loc[gddinfo['crop'] == crop]['gdd2harvest']).astype(int))
        check3 = all(check3)

        if check3 == True:
            weatherdata['t_coef'][i] = max_coef-(weatherdata['gdds'][i] - gddinfo.loc[gddinfo['crop'] == crop]['gdd2mature'])/(gddinfo.loc[gddinfo['crop'] == crop]['gdd2harvest']-gddinfo.loc[gddinfo['crop'] == crop]['gdd2mature'])

        check4 = weatherdata['t_coef'][i] <= 0.22
        check4 = bool(check4)

        if check4 == True:
            weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]

        check5 = weatherdata['t_coef'][i] > 0.22
        check5 = bool(check5)
        if check5 == True:
            weatherdata['e_coef'][i] = 0

        weatherdata['pot_t_cm'] = weatherdata['ET_cm']*weatherdata['t_coef']
        weatherdata['pot_e_cm'] = weatherdata['ET_cm']*weatherdata['e_coef']

    return(weatherdata)

def grow_roots_obs(weatherdata, rootobs):
    rootobs['Date'] = pd.to_datetime(rootobs['Date'])
    atmtest= weatherdata
    atmtest['RootDepth'] = 0
    atmtest = atmtest.merge(rootobs, how= 'left', on= 'Date')
    atmtest.loc[np.isnan(atmtest['Depth']) == False, 'RootDepth'] = atmtest.loc[np.isnan(atmtest['Depth']) == False, 'Depth']

    years = list(set(atmtest['Year']))

    for k in range(len(years)):
        
        root_year = atmtest.loc[(atmtest['Year'] == years[k]) & (np.isnan(atmtest['Depth']) == False)]

        rts = {'Growthrate': ["NA"], 'Day1': ["NA"], 'Day2': ["NA"]}
        allroots = pd.DataFrame(rts)

        for i in range(1, len(root_year)):
            growth = root_year.iloc[i]['Depth'] - root_year.iloc[i-1]['Depth']
            time = root_year.iloc[i]['Date'] - root_year.iloc[i-1]['Date']
            time= time.days
            growthrate = growth/time
            day1 = root_year.iloc[i-1]['Date']
            day2 = root_year.iloc[i]['Date']

            minidata = pd.DataFrame({'Growthrate':[growthrate], 'Day1':[day1], 'Day2':[day2]})
            allroots = pd.concat([allroots, minidata], ignore_index=True)

        allroots = allroots[allroots['Growthrate'] != "NA"]
        allroots.loc[allroots['Growthrate'] <  0, 'Growthrate'] = 0

        for i in range(len(allroots)):
            day1 = allroots.iloc[i]['Day1']
            day2 = allroots.iloc[i]['Day2']
            gr = allroots.iloc[i]['Growthrate']

            for j in range(len(atmtest)):
                if (atmtest.iloc[j]['Date'] > day1) & (atmtest.iloc[j]['Date'] < day2):
                    atmtest['RootDepth'][j] = atmtest['RootDepth'][j-1] + gr
    return(atmtest)

def grow_roots_gdd(weatherdata, cropdata):
    atmtest = weatherdata
    atmtest['RootDepth'] = 0

    for i in range(1,len(atmtest)):
        crop = atmtest['Crop'][i]
        max_depth = cropdata.loc[cropdata['crop'] == crop, 'root.depth.max']
        max_depth

        check1 = (atmtest.iloc[i]['AvgTemp'] > 0) & (atmtest.iloc[i]['Date'] > atmtest.iloc[i]['StartDate'])&( atmtest.iloc[i]['RootDepth'] < max_depth)
        check1 = all(check1)
        if check1 == True:
            atmtest['RootDepth'][i] = atmtest['RootDepth'][i-1] + (atmtest['AvgTemp'][i] * 0.0665)

        check1b = (atmtest.iloc[i]['AvgTemp'] < 0) & (atmtest.iloc[i]['Date'] > atmtest.iloc[i]['StartDate'])&( atmtest.iloc[i]['RootDepth'] < max_depth)
        check1b = all(check1b)
        if check1b == True:
            atmtest['RootDepth'][i] = atmtest['RootDepth'][i-1] 

        check2 = (atmtest.iloc[i]['AvgTemp'] > 0) & (atmtest.iloc[i]['Date'] > atmtest.iloc[i]['StartDate'])&( atmtest.iloc[i]['RootDepth'] >= max_depth)
        check2 = all(check2)
        if check2 == True:
            atmtest['RootDepth'][i] = atmtest['RootDepth'][i-1] 

        check3 = (atmtest.iloc[i]['Date'] > atmtest.iloc[i]['EndDate'])
        if check3 == True:
            atmtest['RootDepth'][i] = 0

    return(atmtest)

# %%
# load inputs for run_hydrus function
atm = pd.read_csv(os.path.join(main_level, '1_Input', weather_csv))
atm['Date'] = pd.to_datetime(atm['Date'])
days = len(atm['Date']) #save length of days column for later steps
irrigation = pd.read_csv(os.path.join(main_level, '1_Input', irgn_csv))
irrigation['Date'] = pd.to_datetime(irrigation['Date'])
cropdates = pd.read_csv(os.path.join(main_level, '1_Input', crop_csv))
gddinfo = pd.read_csv(os.path.join(main_level, '1_Input', gdd_csv))

atm2 = add_gdds(weatherdata=atm, cropdates=cropdates)
atm3 = partition_et(weatherdata= atm2, gddinfo=gddinfo)
atm4b = grow_roots_gdd(weatherdata= atm3, cropdata=gddinfo)

#merge weather and irrigation and add for a total water input column
allatm = atm4b.join(irrigation.set_index('Date'), on='Date')
allatm.loc[np.isnan(allatm['Irrigation_cm']) == True, 'Irrigation_cm'] = 0
allatm['WaterIn_cm'] = allatm['Precip_cm'] + allatm['Irrigation_cm']

#create new dataframe to manipulate to be exactly what is needed for PHydrus (keeping old version w/ temperature info for now)
atm_hydrus = allatm[['WaterIn_cm', 'pot_e_cm', 'pot_t_cm', 'RootDepth']]

#these are required column names: 'tAtm', 'Prec', 'rSoil', 'rRoot', 'hCritA', 'rB', 'hB', 'hT'
atm_hydrus = atm_hydrus.rename(columns={'pot_e_cm':'rSoil', 'WaterIn_cm':'Prec', 'pot_t_cm': 'rRoot'}) #rename columns that are there
atm_hydrus['tAtm'] = range(1,len(atm2)+1)
atm_hydrus['hCritA']= 1000000 #max allowed surface head, this is hydrus default
atm_hydrus['rB']= 0 #bottom flux, is zero for free drainage boundary condition
atm_hydrus['hB']= 0 #groundwater level, is zero if model is not being run with groundwater
atm_hydrus['hT']= 0 #surface pressure head, zero if model uses free drainage

#rearrange to match format input
atm_hydrus = atm_hydrus[['tAtm', 'Prec', 'rSoil', 'rRoot', 'hCritA', 'rB', 'hB', 'hT']]

#Observation Nodes
obs = pd.read_csv(os.path.join(main_level, '1_Input', obs_csv))
obspts = obs.loc[:, "depth"]
obspts= obspts*-1
obslist = list(obspts)

#Timestep list 
timesteps2 = [0.001, 0.003, 0.005, 0.006, 0.0001, 0.0003, 0.0004, 0.01, 0.00002,
            0.00003, 0.00004, 0.00005, 0.00006, 0.00007, 0.00009, 0.0002, 0.0007, 0.0009,
            0.0055, 0.0065, 0.00015, 0.00055, 0.00095] #actual good time steps

atm_hydrus
# Out:
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['Year'][i] = weatherdata.Date.dt.year[i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:58: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   weatherdata['e_coef'][i] = fallow_coef - weatherdata['t_coef'][i]
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:122: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   atmtest['RootDepth'][i] = atmtest['RootDepth'][i-1] + (atmtest['AvgTemp'][i] * 0.0665)
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atmtest['RootDepth'][i] = atmtest['RootDepth'][i-1] + (atmtest['AvgTemp'][i] * 0.0665)
# C:\Users\x63d979\AppData\Local\Temp\ipykernel_19012\3944225467.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.759277603945' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   atmtest['RootDepth'][i] = atmtest['RootDepth'][i-1] + (atmtest['AvgTemp'][i] * 0.0665)
#      tAtm    Prec     rSoil  rRoot   hCritA  rB  hB  hT
# 0       1  0.0000  0.015646    0.0  1000000   0   0   0
# 1       2  0.0000  0.007823    0.0  1000000   0   0   0
# 2       3  0.0000  0.023470    0.0  1000000   0   0   0
# 3       4  0.0000  0.016764    0.0  1000000   0   0   0
# 4       5  0.0000  0.007264    0.0  1000000   0   0   0
# ..    ...     ...       ...    ...      ...  ..  ..  ..
# 751   752  0.0000  0.032969    0.0  1000000   0   0   0
# 752   753  0.0000  0.010058    0.0  1000000   0   0   0
# 753   754  0.0000  0.034087    0.0  1000000   0   0   0
# 754   755  0.0663  0.006147    0.0  1000000   0   0   0
# 755   756  0.0000  0.007264    0.0  1000000   0   0   0
#
# [756 rows x 8 columns]

# %%
# Format vgs to be an array
vgs = pd.read_csv(os.path.join(main_level, '1_Input', vg_csv)).iloc[:, 2:]
vg_len = 17 # 17 for dual perm; 6 for single porosity 
vgs_array = np.array(vgs).reshape(1,len(vgs),vg_len)[0] 
vgs_array
# Out:
# array([[7.9200e-02, 4.4180e-01, 1.5800e-02, 1.4145e+00, 8.1800e+00,
#         5.0000e-01, 1.0000e-02, 3.0000e-01, 1.0000e-03, 1.5000e+00,
#         1.0000e+02, 5.0000e-01, 2.0000e-01, 1.3000e+00, 4.0000e-01,
#         2.0000e+00, 3.0000e-04]])

# %% [markdown]
# ## Testing single forward runs

# %% [markdown]
# ### run_with_timeout test

# %%
# testing a single converging run (took about 2 sec)
from main import run_with_timeout
import numpy as np

fallback = np.full((np.array(calib.drop(columns=["Date"])).shape), np.nan)

hydrus_output = run_with_timeout(
    vgs, calib, atm, atm_hydrus, obs, days, timesteps2,
    fallback=fallback,
    timeout=60  # generous timeout for first test
)

#print("Output:\n", hydrus_output)

# plot observed and simulated results at observation node
plt.figure()
plt.plot(calib["Date"], calib.iloc[:,1], label='Sensor Readings')
plt.plot(calib["Date"], hydrus_output, label='Hydrus Simulation')
plt.xlabel("Date")
plt.ylabel("VWC")
plt.title("Soil Moisture")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ### hydrus setup test

# %%
setup = HydrusSetup(calib, atm, atm_hydrus, obs, days, timesteps2)
mscua = MsCua(setup, dbname='vg_calibration', dbformat='memory')

# %%
# testing HydrusSetup.simulation()
params = {#'thetar': 0.0792,
          #'thetas': 0.4418,
          #'alpha': 0.0158,
          #'n': 1.4145,
          #'ksat': 8.18,
          #'l': 0.5,
          'thetar_macro': 0.01,
          'thetas_macro': 0.3,
          'alpha_macro':0.001,
          'n_macro'	:1.5,
          'ksat_macro': 100,
          'l_macro': 0.5,
          'w': 0.2,
          'beta': 1.3,
          #'gamma':	0.4,
          'a' : 2,
          'ka': 0.0003
}
hydrus_output = setup.simulation(params)

# [[0.0792, 0.4418, 0.0158, 1.4145, 8.18, 0.5, 
# 0.043840933235926964, 0.4286859891757872, # 0.7463167999612352, 
# 5.293836759885242, # 928.3171010916376, 0.5, 0.15271506238356217, 
# 3.2012027630715254, 0.4, 9.691539830274076, 3.194227792921058]]

# plot
plt.figure()
plt.plot(calib["Date"], calib.iloc[:,1], label='Sensor Readings')
plt.plot(calib["Date"], hydrus_output, label='Hydrus Simulation')
plt.xlabel("Date")
plt.ylabel("VWC")
plt.title("Soil Moisture")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
def nse_md(observation: np.ndarray, simulation: np.ndarray, return_dict: bool = False, axis=0):
    if observation.shape[axis] == simulation.shape[axis]:
        mean_observed = np.nanmean(observation, axis=axis)
        # compute numerator and denominator
        numerator = np.nansum((observation - simulation) ** 2, axis=axis)
        denominator = np.nansum((observation - mean_observed) ** 2, axis=axis)
        # compute coefficient
        nse = 1 - (numerator / denominator)
        if return_dict:
            return {'nse': nse}
        else:
            return nse
    else:
        raise ValueError("evaluation and simulation data do not have the same length.")

# %%
# Calculate NSE for working example
observation = np.array(calib.drop(columns=["Date"]))
nse_md(observation=observation, simulation=hydrus_output)

# %% [markdown]
# ## Sensitivity Analysis

# %%
from MS_CUA import LocalSensitivityAnalysis

setup_sa = HydrusSetup(calib, atm, atm_hydrus, obs, days, timesteps2)
lsa = LocalSensitivityAnalysis(setup_sa, params, n_samples=50)
results = lsa.sample()

# %% [markdown]
# ### Visualizations

# %%
results

# %%
lsa.plot()

# %% [markdown]
# ## Iteration 1

# %%
setup1 = HydrusSetup(calib, atm, atm_hydrus, obs, days, timesteps2)
mscua1 = MsCua(setup1, dbname='vg_calibration', dbformat='memory')
mscua1.sample(reps=1000, objfunc_thresholds={'nse': -3.0})
# Out:
# In Memory database initialized...
# plist [Uniform('thetar_macro', [0, 0.1]), Uniform('thetas_macro', [0.2, 0.8]), Uniform('alpha_macro', [0.001, 0.8]), Uniform('n_macro', [1.01, 7]), Uniform('ksat_macro', [1, 1000]), Uniform('l_macro', [0.5, 0.5]), Uniform('w', [0.001, 0.25]), Uniform('beta', [1, 20]), Uniform('a', [0.1, 10]), Uniform('ka', [1e-05, 0.2])]
# Sampling 1000 repetitions of the thetar_macro parameter...
# Sampling 1000 repetitions of the thetas_macro parameter...
# Sampling 1000 repetitions of the alpha_macro parameter...
# Sampling 1000 repetitions of the n_macro parameter...
# Sampling 1000 repetitions of the ksat_macro parameter...
# Sampling 1000 repetitions of the l_macro parameter...
# Sampling 1000 repetitions of the w parameter...
# Sampling 1000 repetitions of the beta parameter...
# Sampling 1000 repetitions of the a parameter...
# Sampling 1000 repetitions of the ka parameter...
# Running model for 1000 repetitions in database...
# simulation:   0%|          | 1/1000 [00:04<1:14:53,  4.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 2/1000 [00:12<1:53:03,  6.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 3/1000 [00:16<1:31:28,  5.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 4/1000 [00:26<1:59:14,  7.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 5/1000 [00:28<1:26:47,  5.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 6/1000 [00:42<2:17:42,  8.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 7/1000 [00:54<2:37:44,  9.53s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 8/1000 [00:59<2:14:48,  8.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 9/1000 [01:03<1:49:38,  6.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 10/1000 [01:07<1:37:59,  5.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 11/1000 [01:12<1:30:05,  5.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 12/1000 [01:15<1:19:31,  4.83s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|▏         | 13/1000 [01:17<1:04:06,  3.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|▏         | 14/1000 [01:27<1:34:05,  5.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 15/1000 [01:38<2:04:30,  7.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 16/1000 [01:46<2:06:00,  7.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 17/1000 [01:50<1:47:29,  6.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 18/1000 [01:55<1:37:27,  5.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 19/1000 [01:59<1:30:03,  5.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 20/1000 [02:04<1:26:19,  5.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 21/1000 [02:08<1:19:30,  4.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 22/1000 [02:12<1:15:06,  4.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 23/1000 [02:17<1:17:26,  4.76s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 24/1000 [02:24<1:26:18,  5.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▎         | 25/1000 [02:29<1:26:50,  5.34s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 26/1000 [02:55<3:04:36, 11.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 27/1000 [03:01<2:38:33,  9.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 28/1000 [03:03<2:00:37,  7.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 29/1000 [03:10<1:59:40,  7.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 30/1000 [03:20<2:13:14,  8.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 31/1000 [03:25<1:54:54,  7.12s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 32/1000 [03:28<1:39:05,  6.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 33/1000 [03:32<1:26:14,  5.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 34/1000 [03:35<1:17:03,  4.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▎         | 35/1000 [05:03<7:54:02, 29.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▎         | 36/1000 [05:06<5:48:49, 21.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▎         | 37/1000 [05:14<4:40:16, 17.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 38/1000 [05:19<3:39:06, 13.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 39/1000 [05:27<3:14:47, 12.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 40/1000 [05:34<2:47:18, 10.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 41/1000 [05:37<2:12:34,  8.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 42/1000 [05:52<2:47:15, 10.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 43/1000 [06:11<3:25:14, 12.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 44/1000 [06:15<2:42:37, 10.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 45/1000 [06:33<3:21:51, 12.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 46/1000 [06:37<2:40:28, 10.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 47/1000 [06:48<2:45:01, 10.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 48/1000 [06:52<2:11:47,  8.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 49/1000 [07:02<2:20:13,  8.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 50/1000 [07:04<1:47:42,  6.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 51/1000 [07:13<1:57:55,  7.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 52/1000 [10:32<17:04:10, 64.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 53/1000 [10:36<12:14:57, 46.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 54/1000 [11:05<10:50:45, 41.27s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 55/1000 [11:11<8:04:55, 30.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 56/1000 [11:33<7:23:07, 28.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 57/1000 [11:39<5:39:22, 21.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 58/1000 [11:42<4:12:24, 16.08s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 59/1000 [11:46<3:11:54, 12.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 60/1000 [12:02<3:29:59, 13.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 61/1000 [12:05<2:42:11, 10.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 62/1000 [12:12<2:27:33,  9.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▋         | 63/1000 [13:01<5:30:45, 21.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▋         | 64/1000 [13:11<4:37:01, 17.76s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▋         | 65/1000 [13:19<3:50:35, 14.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 66/1000 [13:23<3:03:23, 11.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 67/1000 [13:30<2:36:55, 10.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 68/1000 [13:33<2:04:49,  8.04s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 69/1000 [13:58<3:22:23, 13.04s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 70/1000 [14:06<3:00:31, 11.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 71/1000 [14:11<2:29:14,  9.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 72/1000 [14:41<4:05:56, 15.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 73/1000 [14:43<2:59:46, 11.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 74/1000 [14:49<2:31:46,  9.83s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 75/1000 [14:52<2:01:09,  7.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 76/1000 [14:56<1:41:54,  6.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 77/1000 [14:59<1:26:22,  5.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 78/1000 [15:05<1:27:36,  5.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 79/1000 [15:07<1:10:31,  4.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 80/1000 [15:11<1:06:40,  4.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 81/1000 [15:18<1:19:14,  5.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 82/1000 [15:27<1:38:02,  6.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 83/1000 [15:32<1:32:54,  6.08s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 84/1000 [15:38<1:30:42,  5.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 85/1000 [15:46<1:38:04,  6.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▊         | 86/1000 [15:54<1:45:29,  6.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▊         | 87/1000 [16:16<2:55:45, 11.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 88/1000 [16:19<2:17:37,  9.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 89/1000 [16:23<1:51:41,  7.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 90/1000 [16:27<1:37:31,  6.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 91/1000 [16:31<1:26:08,  5.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 92/1000 [16:34<1:15:01,  4.96s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 93/1000 [16:38<1:08:38,  4.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 94/1000 [16:41<1:02:36,  4.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 95/1000 [16:46<1:06:04,  4.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 96/1000 [16:48<54:31,  3.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 97/1000 [17:04<1:54:27,  7.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 98/1000 [17:06<1:27:56,  5.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 99/1000 [17:17<1:49:53,  7.32s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 100/1000 [17:22<1:40:03,  6.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 101/1000 [17:24<1:20:22,  5.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 102/1000 [17:29<1:18:27,  5.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 103/1000 [17:36<1:23:42,  5.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 104/1000 [17:49<1:59:03,  7.97s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 105/1000 [17:53<1:38:43,  6.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 106/1000 [17:59<1:34:50,  6.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 107/1000 [18:03<1:27:11,  5.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 108/1000 [18:09<1:24:29,  5.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 109/1000 [18:28<2:24:01,  9.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 110/1000 [18:30<1:49:49,  7.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 111/1000 [18:37<1:50:17,  7.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 112/1000 [18:41<1:32:34,  6.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█▏        | 113/1000 [18:44<1:19:35,  5.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█▏        | 114/1000 [18:50<1:22:27,  5.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 115/1000 [19:05<2:05:17,  8.49s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 116/1000 [19:09<1:43:48,  7.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 117/1000 [19:11<1:20:20,  5.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 118/1000 [19:18<1:26:36,  5.89s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 119/1000 [19:23<1:22:58,  5.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 120/1000 [19:28<1:22:17,  5.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 121/1000 [19:33<1:18:49,  5.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 122/1000 [19:35<1:05:18,  4.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 123/1000 [19:45<1:25:52,  5.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 124/1000 [19:48<1:14:21,  5.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▎        | 125/1000 [19:51<1:04:23,  4.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 126/1000 [19:54<59:06,  4.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 127/1000 [19:58<58:33,  4.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 128/1000 [20:02<56:59,  3.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 129/1000 [20:05<53:50,  3.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 130/1000 [20:08<51:45,  3.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 131/1000 [20:15<1:05:17,  4.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 132/1000 [20:18<59:51,  4.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 133/1000 [20:21<56:49,  3.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 134/1000 [20:25<54:05,  3.75s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▎        | 135/1000 [20:28<51:42,  3.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▎        | 136/1000 [20:32<53:12,  3.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▎        | 137/1000 [20:40<1:12:13,  5.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 138/1000 [20:46<1:17:26,  5.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 139/1000 [20:52<1:16:54,  5.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 140/1000 [21:02<1:37:30,  6.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 141/1000 [21:11<1:46:41,  7.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 142/1000 [21:13<1:23:29,  5.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 143/1000 [21:14<1:05:27,  4.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 144/1000 [21:18<59:42,  4.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 145/1000 [21:19<48:23,  3.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 146/1000 [21:23<48:03,  3.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 147/1000 [21:33<1:19:24,  5.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 148/1000 [21:37<1:12:01,  5.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 149/1000 [21:41<1:07:04,  4.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 150/1000 [21:44<1:01:03,  4.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 151/1000 [21:48<57:23,  4.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 152/1000 [21:53<1:01:24,  4.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 153/1000 [21:59<1:08:51,  4.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 154/1000 [22:07<1:23:32,  5.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 155/1000 [22:14<1:25:45,  6.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 156/1000 [22:19<1:23:01,  5.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 157/1000 [22:27<1:30:20,  6.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 158/1000 [22:30<1:17:09,  5.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 159/1000 [24:00<7:10:31, 30.72s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 160/1000 [24:16<6:08:36, 26.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 161/1000 [24:20<4:33:57, 19.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 162/1000 [24:40<4:35:47, 19.75s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▋        | 163/1000 [25:03<4:48:08, 20.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▋        | 164/1000 [25:34<5:30:19, 23.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▋        | 165/1000 [25:37<4:04:26, 17.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 166/1000 [25:40<3:04:27, 13.27s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 167/1000 [25:43<2:22:36, 10.27s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 168/1000 [25:51<2:09:20,  9.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 169/1000 [25:54<1:44:01,  7.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 170/1000 [25:57<1:27:01,  6.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 171/1000 [26:17<2:24:50, 10.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 172/1000 [26:22<2:01:07,  8.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 173/1000 [26:26<1:39:33,  7.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 174/1000 [26:34<1:41:22,  7.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 175/1000 [26:35<1:17:21,  5.63s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 176/1000 [27:09<3:14:23, 14.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 177/1000 [27:13<2:29:30, 10.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 178/1000 [27:16<1:58:18,  8.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 179/1000 [27:19<1:35:59,  7.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 180/1000 [27:36<2:17:25, 10.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 181/1000 [27:41<1:56:11,  8.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 182/1000 [27:45<1:38:57,  7.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 183/1000 [27:49<1:25:28,  6.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 184/1000 [27:56<1:27:55,  6.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 185/1000 [28:23<2:50:59, 12.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▊        | 186/1000 [28:27<2:15:05,  9.96s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▊        | 187/1000 [28:51<3:13:31, 14.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 188/1000 [29:07<3:18:42, 14.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 189/1000 [29:12<2:37:07, 11.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 190/1000 [30:21<6:29:26, 28.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 191/1000 [30:24<4:45:04, 21.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 192/1000 [30:42<4:32:20, 20.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 193/1000 [30:50<3:43:54, 16.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 194/1000 [31:28<5:07:40, 22.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 195/1000 [31:32<3:51:06, 17.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 196/1000 [31:35<2:55:53, 13.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 197/1000 [31:38<2:15:58, 10.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 198/1000 [31:47<2:10:52,  9.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 199/1000 [32:42<5:09:31, 23.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 200/1000 [32:45<3:49:22, 17.20s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 201/1000 [32:49<2:54:36, 13.11s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 202/1000 [32:52<2:15:16, 10.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 203/1000 [32:55<1:48:16,  8.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 204/1000 [32:59<1:32:13,  6.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 205/1000 [33:08<1:39:52,  7.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 206/1000 [33:27<2:22:59, 10.81s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 207/1000 [33:32<1:58:43,  8.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 208/1000 [33:34<1:34:01,  7.12s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 209/1000 [33:58<2:38:11, 12.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 210/1000 [34:01<2:03:18,  9.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 211/1000 [34:22<2:49:14, 12.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 212/1000 [34:43<3:21:02, 15.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██▏       | 213/1000 [34:49<2:45:47, 12.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██▏       | 214/1000 [35:02<2:45:09, 12.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 215/1000 [35:05<2:08:02,  9.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 216/1000 [35:16<2:10:28,  9.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 217/1000 [35:19<1:44:02,  7.97s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 218/1000 [35:23<1:27:06,  6.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 219/1000 [35:26<1:13:28,  5.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 220/1000 [35:42<1:53:12,  8.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 221/1000 [35:47<1:39:01,  7.63s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 222/1000 [35:55<1:43:06,  7.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 223/1000 [35:59<1:24:30,  6.53s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 224/1000 [36:53<4:28:44, 20.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▎       | 225/1000 [36:56<3:21:54, 15.63s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 226/1000 [36:59<2:33:27, 11.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 227/1000 [37:04<2:04:15,  9.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 228/1000 [37:23<2:39:25, 12.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 229/1000 [37:26<2:03:34,  9.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 230/1000 [37:32<1:48:36,  8.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 231/1000 [37:37<1:36:25,  7.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 232/1000 [37:45<1:37:17,  7.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 233/1000 [37:48<1:20:27,  6.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 234/1000 [37:56<1:28:47,  6.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▎       | 235/1000 [38:00<1:16:49,  6.03s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▎       | 236/1000 [38:04<1:06:31,  5.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▎       | 237/1000 [38:07<58:46,  4.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 238/1000 [38:08<46:58,  3.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 239/1000 [38:12<45:13,  3.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 240/1000 [39:09<4:07:53, 19.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 241/1000 [39:12<3:05:42, 14.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 242/1000 [39:15<2:22:07, 11.25s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 243/1000 [39:22<2:06:38, 10.04s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 244/1000 [39:31<2:01:32,  9.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 245/1000 [39:34<1:37:20,  7.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 246/1000 [39:38<1:20:33,  6.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 247/1000 [39:41<1:10:38,  5.63s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 248/1000 [39:45<1:02:33,  4.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 249/1000 [39:59<1:36:59,  7.75s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 250/1000 [40:03<1:23:47,  6.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 251/1000 [40:12<1:30:00,  7.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 252/1000 [40:17<1:22:51,  6.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 253/1000 [40:22<1:14:38,  6.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 254/1000 [40:46<2:23:47, 11.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 255/1000 [40:59<2:28:15, 11.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 256/1000 [41:02<1:55:30,  9.32s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 257/1000 [41:07<1:40:08,  8.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 258/1000 [41:11<1:23:34,  6.76s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 259/1000 [41:21<1:36:20,  7.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 260/1000 [41:25<1:19:23,  6.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 261/1000 [41:28<1:07:18,  5.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 262/1000 [41:33<1:05:04,  5.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▋       | 263/1000 [41:36<57:08,  4.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▋       | 264/1000 [42:05<2:26:46, 11.97s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▋       | 265/1000 [42:09<1:57:51,  9.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 266/1000 [42:15<1:44:31,  8.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 267/1000 [42:29<2:03:28, 10.11s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 268/1000 [42:32<1:39:33,  8.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 269/1000 [42:43<1:50:20,  9.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 270/1000 [42:51<1:45:32,  8.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 271/1000 [42:55<1:28:45,  7.30s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 272/1000 [43:01<1:21:09,  6.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 273/1000 [43:04<1:08:38,  5.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 274/1000 [43:07<1:00:34,  5.01s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 275/1000 [43:14<1:06:42,  5.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 276/1000 [43:23<1:19:32,  6.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 277/1000 [43:28<1:14:18,  6.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 278/1000 [43:36<1:19:04,  6.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 279/1000 [43:39<1:06:52,  5.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 280/1000 [43:43<1:00:52,  5.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 281/1000 [43:46<53:56,  4.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 282/1000 [43:58<1:21:55,  6.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 283/1000 [44:20<2:15:49, 11.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 284/1000 [44:25<1:50:05,  9.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 285/1000 [44:28<1:28:22,  7.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▊       | 286/1000 [44:31<1:13:18,  6.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▊       | 287/1000 [44:36<1:09:39,  5.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 288/1000 [44:38<54:26,  4.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 289/1000 [44:58<1:51:05,  9.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 290/1000 [45:03<1:32:38,  7.83s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 291/1000 [46:11<5:06:18, 25.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 292/1000 [46:14<3:47:01, 19.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 293/1000 [46:18<2:50:35, 14.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 294/1000 [47:47<7:15:13, 36.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 295/1000 [47:52<5:21:38, 27.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 296/1000 [47:55<3:56:06, 20.12s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 297/1000 [48:00<2:59:38, 15.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 298/1000 [48:06<2:27:15, 12.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 299/1000 [48:12<2:04:05, 10.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 300/1000 [48:23<2:06:28, 10.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 301/1000 [48:30<1:51:06,  9.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 302/1000 [48:45<2:12:20, 11.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 303/1000 [48:48<1:43:36,  8.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 304/1000 [48:58<1:46:41,  9.20s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 305/1000 [49:55<4:32:05, 23.49s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 306/1000 [49:58<3:21:43, 17.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 307/1000 [50:07<2:51:38, 14.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 308/1000 [51:05<5:18:17, 27.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 309/1000 [51:08<3:53:31, 20.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 310/1000 [51:21<3:28:26, 18.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 311/1000 [51:23<2:32:19, 13.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 312/1000 [51:26<1:57:35, 10.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███▏      | 313/1000 [51:29<1:33:13,  8.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███▏      | 314/1000 [51:33<1:16:08,  6.66s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 315/1000 [51:37<1:07:35,  5.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 316/1000 [51:45<1:14:39,  6.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 317/1000 [51:48<1:03:00,  5.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 318/1000 [51:51<54:58,  4.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 319/1000 [51:53<43:58,  3.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 320/1000 [51:56<41:44,  3.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 321/1000 [52:04<56:41,  5.01s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 322/1000 [52:07<50:40,  4.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 323/1000 [52:13<53:11,  4.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 324/1000 [52:18<55:05,  4.89s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▎      | 325/1000 [52:44<2:08:09, 11.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 326/1000 [52:50<1:47:30,  9.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 327/1000 [52:52<1:21:13,  7.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 328/1000 [52:59<1:20:28,  7.19s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 329/1000 [53:01<1:04:30,  5.77s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 330/1000 [53:30<2:23:16, 12.83s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 331/1000 [53:40<2:13:06, 11.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 332/1000 [53:44<1:47:05,  9.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 333/1000 [53:49<1:30:41,  8.16s/it]
# ...
# simulation:  89%|████████▉ | 891/1000 [2:14:46<13:27,  7.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  89%|████████▉ | 892/1000 [2:14:55<13:50,  7.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  89%|████████▉ | 893/1000 [2:14:58<11:18,  6.34s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  89%|████████▉ | 894/1000 [2:15:02<10:08,  5.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 895/1000 [2:15:05<08:44,  5.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 896/1000 [2:15:09<07:44,  4.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 897/1000 [2:15:16<09:03,  5.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 898/1000 [2:15:20<08:20,  4.91s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 899/1000 [2:16:05<28:46, 17.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 900/1000 [2:16:11<22:33, 13.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 901/1000 [2:16:16<18:22, 11.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 902/1000 [2:17:10<39:09, 23.97s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 903/1000 [2:17:15<29:36, 18.32s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 904/1000 [2:17:23<24:30, 15.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 905/1000 [2:17:27<18:33, 11.72s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 906/1000 [2:17:28<13:39,  8.72s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 907/1000 [2:17:34<12:14,  7.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 908/1000 [2:18:12<25:36, 16.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 909/1000 [2:18:25<23:36, 15.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 910/1000 [2:18:29<18:27, 12.30s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 911/1000 [2:18:33<14:13,  9.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 912/1000 [2:18:50<17:43, 12.08s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████▏| 913/1000 [2:18:54<13:44,  9.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████▏| 914/1000 [2:18:58<11:26,  7.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 915/1000 [2:19:02<09:27,  6.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 916/1000 [2:19:05<07:54,  5.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 917/1000 [2:19:08<06:48,  4.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 918/1000 [2:19:14<06:59,  5.11s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 919/1000 [2:19:46<17:44, 13.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 920/1000 [2:19:49<13:34, 10.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 921/1000 [2:19:55<11:45,  8.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 922/1000 [2:20:02<10:52,  8.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 923/1000 [2:20:07<09:29,  7.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 924/1000 [2:21:03<27:52, 22.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▎| 925/1000 [2:21:23<26:23, 21.11s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 926/1000 [2:21:26<19:26, 15.76s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 927/1000 [2:21:31<15:14, 12.53s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 928/1000 [2:21:37<12:37, 10.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 929/1000 [2:21:41<10:06,  8.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 930/1000 [2:21:44<08:07,  6.97s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 931/1000 [2:21:49<07:22,  6.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 932/1000 [2:21:54<06:43,  5.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 933/1000 [2:22:00<06:36,  5.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 934/1000 [2:22:14<09:19,  8.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▎| 935/1000 [2:22:17<07:30,  6.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▎| 936/1000 [2:22:23<06:51,  6.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▎| 937/1000 [2:22:26<05:45,  5.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 938/1000 [2:22:29<05:02,  4.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 939/1000 [2:22:34<05:00,  4.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 940/1000 [2:22:40<05:09,  5.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 941/1000 [2:22:43<04:31,  4.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 942/1000 [2:22:52<05:29,  5.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 943/1000 [2:23:08<08:31,  8.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 944/1000 [2:23:42<15:10, 16.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 945/1000 [2:23:45<11:18, 12.34s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 946/1000 [2:24:04<12:58, 14.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 947/1000 [2:24:09<10:19, 11.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 948/1000 [2:24:12<07:54,  9.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 949/1000 [2:24:40<12:24, 14.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 950/1000 [2:24:44<09:28, 11.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 951/1000 [2:24:48<07:38,  9.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 952/1000 [2:24:52<06:01,  7.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 953/1000 [2:24:55<04:57,  6.32s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 954/1000 [2:25:04<05:19,  6.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 955/1000 [2:25:08<04:33,  6.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 956/1000 [2:25:11<03:58,  5.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 957/1000 [2:25:17<03:51,  5.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 958/1000 [2:25:23<03:55,  5.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 959/1000 [2:26:57<21:57, 32.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 960/1000 [2:27:02<15:57, 23.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 961/1000 [2:27:06<11:47, 18.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 962/1000 [2:27:10<08:39, 13.66s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▋| 963/1000 [2:27:44<12:14, 19.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▋| 964/1000 [2:27:59<11:02, 18.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▋| 965/1000 [2:28:28<12:39, 21.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 966/1000 [2:28:34<09:30, 16.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 967/1000 [2:28:41<07:37, 13.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 968/1000 [2:28:42<05:27, 10.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 969/1000 [2:28:54<05:30, 10.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 970/1000 [2:29:24<08:11, 16.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 971/1000 [2:29:30<06:23, 13.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 972/1000 [2:29:33<04:47, 10.27s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 973/1000 [2:29:48<05:19, 11.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 974/1000 [2:29:52<04:01,  9.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 975/1000 [2:29:55<03:08,  7.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 976/1000 [2:29:59<02:30,  6.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 977/1000 [2:30:16<03:38,  9.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 978/1000 [2:30:27<03:39,  9.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 979/1000 [2:30:30<02:47,  7.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 980/1000 [2:30:40<02:53,  8.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 981/1000 [2:31:07<04:26, 14.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 982/1000 [2:31:11<03:16, 10.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 983/1000 [2:31:15<02:31,  8.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 984/1000 [2:31:22<02:13,  8.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 985/1000 [2:31:25<01:42,  6.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▊| 986/1000 [2:32:05<03:54, 16.72s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▊| 987/1000 [2:32:13<03:03, 14.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 988/1000 [2:32:33<03:11, 15.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 989/1000 [2:33:09<04:01, 21.96s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 990/1000 [2:33:13<02:44, 16.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 991/1000 [2:33:18<01:58, 13.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 992/1000 [2:33:23<01:25, 10.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 993/1000 [2:33:28<01:01,  8.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 994/1000 [2:33:38<00:56,  9.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 995/1000 [2:33:42<00:38,  7.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 996/1000 [2:33:46<00:25,  6.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 997/1000 [2:34:05<00:31, 10.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 998/1000 [2:34:09<00:16,  8.30s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 999/1000 [2:34:13<00:07,  7.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# Process finished, reading result from file
# simulation output shape: (168, 1)
# Evaluating Objective Function Values...
# Max number of refined parameter sets: 65
# Min number of refined parameter sets: 65
# Calculating the 95PPU...
# Calculating p- and r-factor metrics...
# Max p-factor = 0.7619047619047619
# Min p-factor = 0.7619047619047619
# Min r-factor = 2.5516227887384106
# Max r-factor = 2.5516227887384106
# All models retained more refined parameter sets than the minimun: 25.
# All models had p-factor greater than 0.35

# %%
# Save iteration 1 results
ds1 = mscua1.database.to_xarray()
ds1.to_netcdf(os.path.join(main_level, "3_Results", "Hydrus_MSCUA_Iteration_1.nc"))
# Out:
# c:\Users\x63d979\Documents\HydrusCoding\Hydrus\DualPerm_20260320_gj\2_Code\MS_CUA.py:1086: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for k,v in ds.dims.items():
# <frozen _collections_abc>:894: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.

# %%
#ds1 = xr.open_dataset(os.path.join(main_level, "3_Results", "Hydrus_MSCUA_Iteration_1.nc"))

# %%
# Transform xarray parameters and NSE values into simple csv and save
data = {'thetar' : np.full(len(ds1.repetition), 0.0792),
        'thetas' : np.full(len(ds1.repetition), 0.4418),
        'alpha' : np.full(len(ds1.repetition), 0.0158) ,
        'n' : np.full(len(ds1.repetition), 1.4145) ,
        'ksat' : np.full(len(ds1.repetition), 8.18),
        'l' : np.full(len(ds1.repetition), 0.5),
        'thetar_macro': np.concatenate(ds1['thetar_macro_samples']),
        'thetas_macro': np.concatenate(ds1['thetas_macro_samples']),
        'alpha_macro': np.concatenate(ds1['alpha_macro_samples']),
        'n_macro': np.concatenate(ds1['n_macro_samples']),
        'ksat_macro': np.concatenate(ds1['ksat_macro_samples']),
        'l_macro': np.concatenate(ds1['l_macro_samples']),
        'w': np.concatenate(ds1['w_samples']),
        'beta': np.concatenate(ds1['beta_samples']),
        'gamma' : np.full(len(ds1.repetition), 0.4),
        'a': np.concatenate(ds1['a_samples']),
        'ka': np.concatenate(ds1['ka_samples']),
        'nse': np.concatenate(ds1['nse'])
        }
pd.DataFrame(data).to_csv(os.path.join(main_level, '3_Results', 'MSCUA1.csv'))

# %% [markdown]
# ### Stats

# %%
ds1.best_obj_function
# Out:
# <xarray.DataArray 'best_obj_function' (objective_functions: 1, field: 1)> Size: 8B
# array([[0.13069068]])
# Coordinates:
#   * field                (field) int32 4B 1
#   * objective_functions  (objective_functions) <U3 12B 'nse'

# %%
ds1.best_parameter_set
# Out:
# <xarray.DataArray 'best_parameter_set' (objective_functions: 1, parameters: 10,
#                                         field: 1)> Size: 80B
# array([[[6.73722286e-02],
#         [5.72112846e-01],
#         [3.22574602e-02],
#         [1.88290318e+00],
#         [4.77555120e+02],
#         [5.00000000e-01],
#         [1.58039387e-01],
#         [7.51305467e+00],
#         [3.76631887e+00],
#         [1.80223350e-01]]])
# Coordinates:
#   * field                (field) int32 4B 1
#   * objective_functions  (objective_functions) <U3 12B 'nse'
#   * parameters           (parameters) <U12 480B 'thetar_macro' ... 'ka'

# %%
ana = MsCuaAnalyzer(ds1)

# %% [markdown]
# ### Visualizations

# %%
param_names = ['thetar_macro', 'thetas_macro', 'alpha_macro', 'n_macro', 'ksat_macro', 'l_macro',
               'w', 'beta', 'a', 'ka']
for name in param_names:
    ana.plot_refined_parameters(param=name, indx=0)

# %% [markdown]
# ## Iteration 2

# %%
refined = mscua1.database.refined_parameters  # dict of param_name -> array with NaNs
setup2 = HydrusSetup(calib, atm, atm_hydrus, obs, days, timesteps2, params=refined)
mscua2 = MsCua(setup2, dbname='iter2', dbformat='memory')
mscua2.sample(reps=1000, objfunc_thresholds={'nse': -1.5})
# Out:
# In Memory database initialized...
# plist [Uniform('thetar_macro', [0, 0.1]), Uniform('thetas_macro', [0.2, 0.8]), Uniform('alpha_macro', [0.001, 0.8]), Uniform('n_macro', [1.01, 7]), Uniform('ksat_macro', [1, 1000]), Uniform('l_macro', [0.5, 0.5]), Uniform('w', [0.001, 0.25]), Uniform('beta', [1, 20]), Uniform('a', [0.1, 10]), Uniform('ka', [1e-05, 0.2])]
# Sampling 1000 repetitions of the thetar_macro parameter...
# Sampling 1000 repetitions of the thetas_macro parameter...
# Sampling 1000 repetitions of the alpha_macro parameter...
# Sampling 1000 repetitions of the n_macro parameter...
# Sampling 1000 repetitions of the ksat_macro parameter...
# Sampling 1000 repetitions of the l_macro parameter...
# Sampling 1000 repetitions of the w parameter...
# Sampling 1000 repetitions of the beta parameter...
# Sampling 1000 repetitions of the a parameter...
# Sampling 1000 repetitions of the ka parameter...
# Running model for 1000 repetitions in database...
# simulation:   0%|          | 1/1000 [00:27<7:29:35, 27.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 2/1000 [00:31<3:50:28, 13.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 3/1000 [00:34<2:29:54,  9.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 4/1000 [00:39<1:58:19,  7.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   0%|          | 5/1000 [00:42<1:35:00,  5.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 6/1000 [00:45<1:21:44,  4.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 7/1000 [00:49<1:15:33,  4.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 8/1000 [00:53<1:10:21,  4.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 9/1000 [01:02<1:34:08,  5.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 10/1000 [01:42<4:30:10, 16.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 11/1000 [01:45<3:24:01, 12.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|          | 12/1000 [01:49<2:39:00,  9.66s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|▏         | 13/1000 [01:53<2:10:35,  7.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   1%|▏         | 14/1000 [02:01<2:12:17,  8.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 15/1000 [02:09<2:13:09,  8.11s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 16/1000 [02:12<1:48:55,  6.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 17/1000 [02:25<2:16:57,  8.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 18/1000 [02:46<3:20:47, 12.27s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 19/1000 [02:56<3:08:54, 11.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 20/1000 [03:02<2:41:35,  9.89s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 21/1000 [03:21<3:24:53, 12.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 22/1000 [04:28<7:53:33, 29.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 23/1000 [04:34<5:58:30, 22.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▏         | 24/1000 [04:36<4:22:27, 16.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   2%|▎         | 25/1000 [04:38<3:12:09, 11.83s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 26/1000 [06:27<11:04:05, 40.91s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 27/1000 [06:30<8:00:03, 29.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 28/1000 [06:32<5:43:20, 21.19s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 29/1000 [06:37<4:25:43, 16.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 30/1000 [06:40<3:21:19, 12.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 31/1000 [06:44<2:38:01,  9.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 32/1000 [06:47<2:06:07,  7.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 33/1000 [07:16<3:46:59, 14.08s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   3%|▎         | 34/1000 [07:21<3:02:41, 11.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▎         | 35/1000 [07:23<2:19:43,  8.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▎         | 36/1000 [07:28<2:03:22,  7.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▎         | 37/1000 [08:25<5:57:17, 22.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 38/1000 [08:33<4:47:38, 17.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 39/1000 [08:34<3:29:47, 13.10s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 40/1000 [08:38<2:46:33, 10.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 41/1000 [08:44<2:24:40,  9.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 42/1000 [08:51<2:14:02,  8.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 43/1000 [08:57<2:02:21,  7.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 44/1000 [09:01<1:46:09,  6.66s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   4%|▍         | 45/1000 [09:05<1:29:50,  5.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 46/1000 [09:10<1:28:24,  5.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 47/1000 [09:50<4:11:19, 15.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 48/1000 [09:53<3:11:08, 12.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▍         | 49/1000 [09:57<2:31:08,  9.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 50/1000 [09:58<1:53:20,  7.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 51/1000 [10:09<2:09:03,  8.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 52/1000 [10:12<1:45:28,  6.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 53/1000 [12:00<9:43:04, 36.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   5%|▌         | 54/1000 [12:59<11:26:44, 43.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 55/1000 [13:19<9:33:55, 36.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 56/1000 [13:22<6:59:50, 26.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 57/1000 [14:00<7:49:03, 29.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 58/1000 [14:04<5:47:52, 22.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 59/1000 [14:09<4:27:47, 17.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 60/1000 [14:13<3:27:39, 13.25s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 61/1000 [14:17<2:41:19, 10.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▌         | 62/1000 [14:24<2:25:51,  9.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▋         | 63/1000 [14:56<4:13:12, 16.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▋         | 64/1000 [15:09<3:58:51, 15.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   6%|▋         | 65/1000 [15:13<3:03:43, 11.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 66/1000 [15:22<2:50:17, 10.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 67/1000 [15:42<3:31:18, 13.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 68/1000 [15:45<2:43:04, 10.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 69/1000 [15:53<2:33:21,  9.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 70/1000 [15:57<2:02:30,  7.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 71/1000 [16:01<1:43:26,  6.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 72/1000 [16:04<1:27:32,  5.66s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 73/1000 [17:18<6:43:40, 26.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   7%|▋         | 74/1000 [17:27<5:24:24, 21.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 75/1000 [17:32<4:11:49, 16.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 76/1000 [18:12<5:57:44, 23.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 77/1000 [18:16<4:30:54, 17.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 78/1000 [19:12<7:28:23, 29.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 79/1000 [19:26<6:17:57, 24.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 80/1000 [19:40<5:27:02, 21.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 81/1000 [19:44<4:05:41, 16.04s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 82/1000 [19:49<3:17:08, 12.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 83/1000 [20:30<5:25:31, 21.30s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 84/1000 [20:33<4:03:17, 15.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   8%|▊         | 85/1000 [20:43<3:33:35, 14.01s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▊         | 86/1000 [20:46<2:44:04, 10.77s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▊         | 87/1000 [20:56<2:40:25, 10.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 88/1000 [21:00<2:11:50,  8.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 89/1000 [21:04<1:46:55,  7.04s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 90/1000 [21:07<1:29:23,  5.89s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 91/1000 [21:11<1:22:56,  5.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 92/1000 [21:20<1:37:04,  6.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 93/1000 [21:23<1:23:12,  5.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:   9%|▉         | 94/1000 [21:28<1:17:55,  5.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 95/1000 [21:43<2:01:25,  8.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 96/1000 [21:45<1:34:46,  6.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 97/1000 [21:48<1:20:57,  5.38s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 98/1000 [22:19<3:15:49, 13.03s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|▉         | 99/1000 [22:23<2:34:29, 10.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 100/1000 [22:26<2:03:22,  8.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 101/1000 [22:32<1:53:03,  7.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 102/1000 [22:35<1:30:30,  6.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 103/1000 [22:39<1:23:55,  5.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 104/1000 [22:48<1:38:24,  6.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  10%|█         | 105/1000 [22:51<1:23:23,  5.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 106/1000 [22:56<1:18:24,  5.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 107/1000 [23:00<1:11:07,  4.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 108/1000 [23:18<2:09:47,  8.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 109/1000 [23:26<2:08:00,  8.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 110/1000 [23:36<2:13:26,  9.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 111/1000 [23:49<2:30:09, 10.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█         | 112/1000 [23:53<2:05:22,  8.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█▏        | 113/1000 [23:58<1:47:49,  7.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  11%|█▏        | 114/1000 [24:01<1:29:39,  6.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 115/1000 [24:06<1:27:17,  5.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 116/1000 [24:18<1:51:09,  7.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 117/1000 [24:25<1:48:57,  7.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 118/1000 [24:29<1:32:46,  6.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 119/1000 [24:32<1:19:53,  5.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 120/1000 [24:42<1:41:12,  6.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 121/1000 [25:11<3:14:58, 13.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 122/1000 [25:14<2:31:21, 10.34s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 123/1000 [25:18<2:01:10,  8.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▏        | 124/1000 [25:23<1:48:52,  7.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  12%|█▎        | 125/1000 [25:27<1:34:00,  6.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 126/1000 [25:40<2:01:51,  8.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 127/1000 [25:43<1:40:05,  6.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 128/1000 [25:48<1:29:40,  6.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 129/1000 [25:49<1:09:34,  4.79s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 130/1000 [26:11<2:23:00,  9.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 131/1000 [26:15<1:54:35,  7.91s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 132/1000 [26:25<2:04:12,  8.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 133/1000 [27:16<5:07:55, 21.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  13%|█▎        | 134/1000 [27:37<5:06:56, 21.27s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▎        | 135/1000 [27:55<4:52:08, 20.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▎        | 136/1000 [27:59<3:41:47, 15.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▎        | 137/1000 [28:04<2:56:35, 12.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 138/1000 [28:10<2:29:25, 10.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 139/1000 [28:13<1:58:18,  8.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 140/1000 [28:19<1:46:30,  7.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 141/1000 [28:22<1:30:56,  6.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 142/1000 [29:41<6:38:30, 27.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 143/1000 [29:52<5:28:50, 23.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 144/1000 [30:01<4:28:27, 18.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  14%|█▍        | 145/1000 [30:05<3:24:20, 14.34s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 146/1000 [30:09<2:37:26, 11.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 147/1000 [30:12<2:04:07,  8.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 148/1000 [30:16<1:42:49,  7.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▍        | 149/1000 [30:20<1:28:47,  6.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 150/1000 [30:23<1:15:34,  5.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 151/1000 [30:27<1:08:53,  4.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 152/1000 [30:34<1:21:17,  5.75s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 153/1000 [30:38<1:10:31,  5.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  15%|█▌        | 154/1000 [30:41<1:04:32,  4.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 155/1000 [30:45<1:00:24,  4.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 156/1000 [30:46<49:19,  3.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 157/1000 [30:50<48:13,  3.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 158/1000 [31:04<1:32:15,  6.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 159/1000 [31:07<1:18:20,  5.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 160/1000 [31:24<2:06:45,  9.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 161/1000 [31:28<1:47:17,  7.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▌        | 162/1000 [31:33<1:35:42,  6.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▋        | 163/1000 [31:44<1:49:24,  7.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▋        | 164/1000 [31:48<1:35:43,  6.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  16%|█▋        | 165/1000 [31:53<1:25:55,  6.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 166/1000 [31:57<1:17:20,  5.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 167/1000 [32:09<1:45:28,  7.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 168/1000 [32:13<1:28:19,  6.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 169/1000 [32:16<1:16:21,  5.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 170/1000 [32:20<1:07:52,  4.91s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 171/1000 [32:37<1:57:53,  8.53s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 172/1000 [32:40<1:36:46,  7.01s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 173/1000 [32:43<1:20:52,  5.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  17%|█▋        | 174/1000 [32:46<1:09:13,  5.03s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 175/1000 [32:50<1:01:31,  4.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 176/1000 [32:58<1:15:34,  5.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 177/1000 [33:01<1:07:01,  4.89s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 178/1000 [33:17<1:50:53,  8.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 179/1000 [33:35<2:32:28, 11.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 180/1000 [33:38<1:59:51,  8.77s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 181/1000 [33:42<1:40:22,  7.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 182/1000 [33:45<1:21:00,  5.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 183/1000 [33:49<1:11:58,  5.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 184/1000 [33:52<1:03:56,  4.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  18%|█▊        | 185/1000 [33:58<1:10:28,  5.19s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▊        | 186/1000 [34:01<1:02:19,  4.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▊        | 187/1000 [34:05<57:46,  4.26s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 188/1000 [34:09<55:22,  4.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 189/1000 [34:12<51:23,  3.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 190/1000 [34:15<49:01,  3.63s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 191/1000 [34:20<52:51,  3.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 192/1000 [34:23<50:23,  3.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 193/1000 [34:51<2:26:50, 10.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  19%|█▉        | 194/1000 [34:56<2:06:45,  9.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 195/1000 [35:00<1:41:54,  7.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 196/1000 [35:03<1:24:19,  6.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 197/1000 [35:26<2:29:08, 11.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 198/1000 [35:39<2:40:21, 12.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|█▉        | 199/1000 [35:41<1:58:15,  8.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 200/1000 [36:11<3:22:22, 15.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 201/1000 [36:19<2:53:20, 13.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 202/1000 [36:21<2:08:01,  9.63s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 203/1000 [36:27<1:54:14,  8.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 204/1000 [36:31<1:38:13,  7.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  20%|██        | 205/1000 [36:43<1:56:16,  8.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 206/1000 [36:48<1:39:14,  7.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 207/1000 [36:55<1:37:17,  7.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 208/1000 [36:58<1:21:10,  6.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 209/1000 [37:00<1:03:19,  4.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 210/1000 [37:03<56:56,  4.32s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 211/1000 [37:07<55:24,  4.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██        | 212/1000 [37:10<51:04,  3.89s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██▏       | 213/1000 [37:19<1:11:26,  5.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  21%|██▏       | 214/1000 [37:52<2:56:59, 13.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 215/1000 [37:58<2:29:21, 11.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 216/1000 [38:06<2:15:53, 10.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 217/1000 [38:10<1:51:38,  8.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 218/1000 [38:14<1:30:29,  6.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 219/1000 [38:17<1:15:35,  5.81s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 220/1000 [38:18<59:08,  4.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 221/1000 [38:25<1:07:19,  5.19s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 222/1000 [38:28<59:35,  4.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 223/1000 [38:53<2:16:11, 10.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▏       | 224/1000 [38:56<1:47:19,  8.30s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  22%|██▎       | 225/1000 [39:02<1:37:12,  7.53s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 226/1000 [39:18<2:11:11, 10.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 227/1000 [39:22<1:48:43,  8.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 228/1000 [39:27<1:35:33,  7.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 229/1000 [39:45<2:13:52, 10.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 230/1000 [39:49<1:51:27,  8.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 231/1000 [39:53<1:30:16,  7.04s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 232/1000 [40:21<2:50:54, 13.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 233/1000 [40:24<2:11:32, 10.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  23%|██▎       | 234/1000 [40:28<1:46:38,  8.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▎       | 235/1000 [40:31<1:26:44,  6.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▎       | 236/1000 [40:35<1:17:02,  6.05s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▎       | 237/1000 [40:38<1:05:56,  5.19s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 238/1000 [40:46<1:16:16,  6.01s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 239/1000 [40:53<1:17:39,  6.12s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 240/1000 [40:56<1:07:34,  5.34s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 241/1000 [41:00<1:01:21,  4.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 242/1000 [41:02<49:33,  3.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 243/1000 [41:05<47:28,  3.76s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 244/1000 [41:11<57:31,  4.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  24%|██▍       | 245/1000 [41:15<52:18,  4.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 246/1000 [41:26<1:20:26,  6.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 247/1000 [41:41<1:51:56,  8.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 248/1000 [41:44<1:30:02,  7.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▍       | 249/1000 [41:52<1:32:02,  7.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 250/1000 [41:57<1:25:17,  6.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 251/1000 [42:01<1:14:03,  5.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 252/1000 [42:05<1:04:54,  5.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 253/1000 [42:10<1:03:31,  5.10s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  25%|██▌       | 254/1000 [42:13<56:03,  4.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 255/1000 [42:17<55:03,  4.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 256/1000 [42:34<1:39:37,  8.03s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 257/1000 [42:37<1:21:17,  6.57s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 258/1000 [42:40<1:09:50,  5.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 259/1000 [42:45<1:06:34,  5.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 260/1000 [42:48<58:23,  4.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 261/1000 [42:52<56:46,  4.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▌       | 262/1000 [43:13<1:55:26,  9.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▋       | 263/1000 [43:17<1:36:27,  7.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▋       | 264/1000 [43:20<1:18:57,  6.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  26%|██▋       | 265/1000 [44:06<3:43:24, 18.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 266/1000 [44:25<3:43:46, 18.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 267/1000 [44:32<3:03:03, 14.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 268/1000 [44:47<3:04:36, 15.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 269/1000 [44:51<2:20:43, 11.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 270/1000 [44:54<1:51:39,  9.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 271/1000 [45:01<1:42:41,  8.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 272/1000 [45:04<1:24:00,  6.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 273/1000 [45:54<4:00:33, 19.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  27%|██▋       | 274/1000 [46:01<3:13:21, 15.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 275/1000 [46:06<2:33:46, 12.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 276/1000 [46:11<2:03:13, 10.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 277/1000 [46:14<1:37:50,  8.12s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 278/1000 [46:17<1:20:29,  6.69s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 279/1000 [46:42<2:26:51, 12.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 280/1000 [46:58<2:38:38, 13.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 281/1000 [50:35<14:51:52, 74.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 282/1000 [50:38<10:34:59, 53.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 283/1000 [50:42<7:35:59, 38.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 284/1000 [50:45<5:30:10, 27.67s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  28%|██▊       | 285/1000 [50:59<4:39:13, 23.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▊       | 286/1000 [51:00<3:20:47, 16.87s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▊       | 287/1000 [51:04<2:32:26, 12.83s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 288/1000 [51:07<1:58:04,  9.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 289/1000 [51:24<2:24:08, 12.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 290/1000 [51:28<1:53:39,  9.60s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 291/1000 [51:34<1:41:20,  8.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 292/1000 [51:38<1:25:15,  7.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 293/1000 [51:41<1:11:40,  6.08s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  29%|██▉       | 294/1000 [51:49<1:16:41,  6.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 295/1000 [51:57<1:21:17,  6.92s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 296/1000 [52:00<1:09:01,  5.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 297/1000 [52:19<1:54:57,  9.81s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 298/1000 [52:23<1:31:58,  7.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|██▉       | 299/1000 [52:28<1:24:17,  7.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 300/1000 [52:31<1:09:56,  5.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 301/1000 [52:37<1:08:05,  5.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 302/1000 [52:42<1:04:11,  5.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 303/1000 [52:44<52:03,  4.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 304/1000 [52:49<53:58,  4.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  30%|███       | 305/1000 [52:54<54:57,  4.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 306/1000 [52:57<49:49,  4.31s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 307/1000 [53:02<51:35,  4.47s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 308/1000 [53:06<51:14,  4.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 309/1000 [53:09<46:49,  4.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 310/1000 [53:13<44:13,  3.85s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 311/1000 [53:17<45:42,  3.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███       | 312/1000 [53:22<47:36,  4.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███▏      | 313/1000 [53:53<2:20:03, 12.23s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  31%|███▏      | 314/1000 [53:56<1:49:10,  9.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 315/1000 [54:09<1:59:27, 10.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 316/1000 [54:15<1:44:30,  9.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 317/1000 [54:20<1:30:51,  7.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 318/1000 [54:25<1:21:01,  7.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 319/1000 [54:39<1:44:21,  9.19s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 320/1000 [54:50<1:49:42,  9.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 321/1000 [54:54<1:30:29,  8.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 322/1000 [55:01<1:26:34,  7.66s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 323/1000 [55:09<1:28:41,  7.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▏      | 324/1000 [55:13<1:13:21,  6.51s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  32%|███▎      | 325/1000 [55:16<1:01:52,  5.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 326/1000 [55:21<1:00:47,  5.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 327/1000 [55:30<1:13:49,  6.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 328/1000 [55:34<1:05:24,  5.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 329/1000 [55:43<1:13:41,  6.59s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 330/1000 [55:50<1:16:04,  6.81s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 331/1000 [56:03<1:36:07,  8.62s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 332/1000 [56:23<2:15:58, 12.21s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  33%|███▎      | 333/1000 [56:57<3:25:48, 18.51s/it]
# ...
# simulation:  89%|████████▉ | 891/1000 [2:21:03<39:02, 21.49s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  89%|████████▉ | 892/1000 [2:21:46<49:55, 27.73s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  89%|████████▉ | 893/1000 [2:21:49<36:17, 20.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  89%|████████▉ | 894/1000 [2:22:09<35:41, 20.20s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 895/1000 [2:22:13<27:01, 15.45s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 896/1000 [2:22:17<20:41, 11.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 897/1000 [2:22:21<16:20,  9.52s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 898/1000 [2:22:23<12:27,  7.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|████████▉ | 899/1000 [2:22:26<10:12,  6.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 900/1000 [2:22:27<07:50,  4.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 901/1000 [2:22:51<17:05, 10.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 902/1000 [2:22:56<14:17,  8.75s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 903/1000 [2:22:59<11:32,  7.14s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 904/1000 [2:23:11<13:23,  8.37s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  90%|█████████ | 905/1000 [2:23:14<10:46,  6.80s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 906/1000 [2:23:17<09:10,  5.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 907/1000 [2:23:26<10:18,  6.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 908/1000 [2:23:31<09:17,  6.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 909/1000 [2:23:38<09:43,  6.41s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 910/1000 [2:23:41<08:19,  5.56s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 911/1000 [2:23:48<08:44,  5.90s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████ | 912/1000 [2:23:52<07:49,  5.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████▏| 913/1000 [2:23:57<07:20,  5.07s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  91%|█████████▏| 914/1000 [2:24:00<06:26,  4.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 915/1000 [2:24:06<07:18,  5.16s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 916/1000 [2:24:10<06:40,  4.77s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 917/1000 [2:24:13<05:55,  4.29s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 918/1000 [2:24:36<13:10,  9.64s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 919/1000 [2:24:40<10:59,  8.15s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 920/1000 [2:24:44<09:01,  6.77s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 921/1000 [2:24:48<07:49,  5.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 922/1000 [2:24:51<06:37,  5.10s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 923/1000 [2:24:58<07:09,  5.58s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▏| 924/1000 [2:26:29<39:41, 31.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  92%|█████████▎| 925/1000 [2:26:52<36:11, 28.95s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 926/1000 [2:26:57<26:48, 21.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 927/1000 [2:27:04<20:50, 17.12s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 928/1000 [2:27:29<23:31, 19.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 929/1000 [2:27:38<19:23, 16.39s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 930/1000 [2:27:42<14:48, 12.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 931/1000 [2:27:45<11:19,  9.84s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 932/1000 [2:27:55<11:04,  9.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 933/1000 [2:27:59<08:54,  7.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  93%|█████████▎| 934/1000 [2:28:03<07:32,  6.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▎| 935/1000 [2:28:06<06:13,  5.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▎| 936/1000 [2:28:09<05:18,  4.98s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▎| 937/1000 [2:28:11<04:09,  3.96s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 938/1000 [2:28:14<03:51,  3.74s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 939/1000 [2:28:22<05:07,  5.03s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 940/1000 [2:28:25<04:27,  4.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 941/1000 [2:28:30<04:22,  4.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 942/1000 [2:28:35<04:32,  4.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 943/1000 [2:28:39<04:18,  4.54s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 944/1000 [2:29:34<18:22, 19.68s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  94%|█████████▍| 945/1000 [2:30:03<20:36, 22.48s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 946/1000 [2:30:07<15:04, 16.76s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 947/1000 [2:30:11<11:34, 13.11s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 948/1000 [2:30:58<20:06, 23.20s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▍| 949/1000 [2:31:02<14:52, 17.49s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 950/1000 [2:31:05<11:03, 13.28s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 951/1000 [2:31:12<09:07, 11.17s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 952/1000 [2:32:21<22:48, 28.50s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 953/1000 [2:32:30<17:49, 22.75s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  95%|█████████▌| 954/1000 [2:32:34<13:10, 17.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 955/1000 [2:33:13<17:39, 23.55s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 956/1000 [2:33:48<19:48, 27.01s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 957/1000 [2:33:51<14:14, 19.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 958/1000 [2:33:54<10:24, 14.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 959/1000 [2:34:02<08:40, 12.70s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 960/1000 [2:34:03<06:14,  9.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 961/1000 [2:34:06<04:51,  7.49s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▌| 962/1000 [2:34:54<12:25, 19.61s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▋| 963/1000 [2:34:59<09:16, 15.03s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▋| 964/1000 [2:35:02<06:52, 11.46s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  96%|█████████▋| 965/1000 [2:35:29<09:28, 16.24s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 966/1000 [2:35:32<06:59, 12.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 967/1000 [2:35:37<05:32, 10.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 968/1000 [2:35:41<04:20,  8.13s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 969/1000 [2:35:45<03:33,  6.88s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 970/1000 [2:35:48<02:53,  5.78s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 971/1000 [2:36:21<06:41, 13.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 972/1000 [2:36:39<07:09, 15.33s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 973/1000 [2:36:48<06:00, 13.36s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  97%|█████████▋| 974/1000 [2:37:18<07:58, 18.42s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 975/1000 [2:37:22<05:48, 13.93s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 976/1000 [2:37:36<05:36, 14.02s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 977/1000 [2:37:40<04:15, 11.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 978/1000 [2:37:44<03:16,  8.91s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 979/1000 [2:37:48<02:35,  7.40s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 980/1000 [2:37:52<02:08,  6.44s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 981/1000 [2:38:19<03:56, 12.43s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 982/1000 [2:38:22<02:56,  9.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 983/1000 [2:38:30<02:36,  9.22s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 984/1000 [2:38:35<02:07,  7.94s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  98%|█████████▊| 985/1000 [2:38:40<01:45,  7.00s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▊| 986/1000 [2:38:50<01:51,  7.99s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▊| 987/1000 [2:38:55<01:30,  6.97s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 988/1000 [2:38:56<01:04,  5.35s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 989/1000 [2:39:00<00:52,  4.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 990/1000 [2:39:09<01:01,  6.18s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 991/1000 [2:39:22<01:12,  8.06s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 992/1000 [2:39:25<00:53,  6.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 993/1000 [2:39:29<00:41,  5.86s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation:  99%|█████████▉| 994/1000 [2:39:36<00:36,  6.08s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 995/1000 [2:39:37<00:23,  4.71s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 996/1000 [2:39:41<00:17,  4.49s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 997/1000 [2:39:44<00:12,  4.09s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 998/1000 [2:39:48<00:07,  3.82s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# simulation: 100%|█████████▉| 999/1000 [2:39:51<00:03,  3.65s/it]
# Process finished, reading result from file
# simulation output shape: (168, 1)
# Process finished, reading result from file
# simulation output shape: (168, 1)
# Evaluating Objective Function Values...
# Max number of refined parameter sets: 48
# Min number of refined parameter sets: 48
# Calculating the 95PPU...
# Calculating p- and r-factor metrics...
# Max p-factor = 0.44047619047619047
# Min p-factor = 0.44047619047619047
# Min r-factor = 1.6466094859406781
# Max r-factor = 1.6466094859406781
# All models retained more refined parameter sets than the minimun: 25.
# All models had p-factor greater than 0.35

# %%
# Save iteration 2 results
ds2 = mscua2.database.to_xarray()
ds2.to_netcdf(os.path.join(main_level, "3_Results", "Hydrus_MSCUA_Iteration_2.nc"))
# Out:
# c:\Users\x63d979\Documents\HydrusCoding\Hydrus\DualPerm_20260320_gj\2_Code\MS_CUA.py:1086: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for k,v in ds.dims.items():
# <frozen _collections_abc>:894: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.

# %%
#ds2 = xr.open_dataset(os.path.join(main_level, "3_Results", "Hydrus_MSCUA_Iteration_2.nc"))

# %%
# Transform xarray parameters and NSE values into simple csv and save
data = {'thetar' : np.full(len(ds2.repetition), 0.0792),
        'thetas' : np.full(len(ds2.repetition), 0.4418),
        'alpha' : np.full(len(ds2.repetition), 0.0158) ,
        'n' : np.full(len(ds2.repetition), 1.4145) ,
        'ksat' : np.full(len(ds2.repetition), 8.18),
        'l' : np.full(len(ds2.repetition), 0.5),
        'thetar_macro': np.concatenate(ds2['thetar_macro_samples']),
        'thetas_macro': np.concatenate(ds2['thetas_macro_samples']),
        'alpha_macro': np.concatenate(ds2['alpha_macro_samples']),
        'n_macro': np.concatenate(ds2['n_macro_samples']),
        'ksat_macro': np.concatenate(ds2['ksat_macro_samples']),
        'l_macro': np.concatenate(ds2['l_macro_samples']),
        'w': np.concatenate(ds2['w_samples']),
        'beta': np.concatenate(ds2['beta_samples']),
        'gamma' : np.full(len(ds2.repetition), 0.4),
        'a': np.concatenate(ds2['a_samples']),
        'ka': np.concatenate(ds2['ka_samples']),
        'nse': np.concatenate(ds2['nse'])
        }
pd.DataFrame(data).to_csv(os.path.join(main_level, '3_Results', 'MSCUA2.csv'))

# %% [markdown]
# ### Visualizations
