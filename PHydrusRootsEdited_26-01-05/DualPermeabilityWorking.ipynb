# %%
import pandas as pd

vgmod0 = [0.05, 0.45, 0.001, 1.3, 12, 0.5]
vg0pd = pd.Series(vgmod0)
words= "testing if this works"

lines = [f"{words}"]

lines.append(vg0pd.to_string(index=False))
lines.append("\n")
# Out:
# ['testing if this works', ' 0.050\n 0.450\n 0.001\n 1.300\n12.000\n 0.500', '\n']

# %%
models = {
            0: ["thr", "ths", "Alfa", "n", "Ks", "l"],
            1: ["thr", "ths", "Alfa", "n", "Ks", "l", "thm", "tha", "thk",
                "Kk"],
            2: ["thr", "ths", "Alfa", "n", "Ks", "l"],
            3: ["thr", "ths", "Alfa", "n", "Ks", "l"],
            4: ["thr", "ths", "Alfa", "n", "Ks", "l"],
            5: ["thr", "ths", "Alfa", "n", "Ks", "l", "w", "Alfa2", "n2"],
            6: ["thr", "ths", "Alfa", "n", "Ks", "l", "thr_im", "ths_im",
                "omega"],
            7: ["thr", "ths", "Alfa", "n", "Ks", "l", "thr_im", "ths_im",
                "Alfa_im", "n_im", "Ka"],
            9: ["thr", "ths", "Alfa", "n", "Ks", "l", "thrFr", "thsFr", "AlfaFr", "nFr", "lFr", "W", "beta", "gamma", "a", "Ka"]
        }

level2 = models[9]
level1 = ["water"] * len(level2)
level1
# Out:
# ['water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water']
